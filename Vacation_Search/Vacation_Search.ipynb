# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_database/WeatherPy_database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     byron bay      AU -28.6500  153.6167     79.95        62
# 1        1  punta arenas      CL -53.1500  -70.9167     53.11        37
# 2        2        faanui      PF -16.4833 -151.7500     81.16        58
# 3        3   new norfolk      AU -42.7826  147.0587     72.72        46
# 4        4       cayenne      GF   4.9333  -52.3333     73.44       100
#
#    Cloudiness  Wind Speed           Weather
# 0          65        9.46     broken clouds
# 1           0       23.02         clear sky
# 2          97       14.29   overcast clouds
# 3          31        2.98  scattered clouds
# 4          75        0.00     broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 20
# What is the maximum temperature you would like for your trip? 100

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]

# Display sample data
preferred_cities_df
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0     byron bay      AU -28.6500  153.6167     79.95        62
# 1          1  punta arenas      CL -53.1500  -70.9167     53.11        37
# 2          2        faanui      PF -16.4833 -151.7500     81.16        58
# 3          3   new norfolk      AU -42.7826  147.0587     72.72        46
# 4          4       cayenne      GF   4.9333  -52.3333     73.44       100
# ..       ...           ...     ...      ...       ...       ...       ...
# 715      715      sobolevo      RU  54.4299   31.8996     30.34        96
# 716      716         dubbo      AU -32.2500  148.6167     80.73        44
# 718      718      purepero      MX  19.9167 -102.0167     64.26        32
# 719      719        kijang      KR  35.2442  129.2139     31.73        25
# 720      720   san quintin      MX  30.4833 -115.9500     60.30        81
#
#      Cloudiness  Wind Speed           Weather
# 0            65        9.46     broken clouds
# 1             0       23.02         clear sky
# 2            97       14.29   overcast clouds
# 3            31        2.98  scattered clouds
# 4            75        0.00     broken clouds
# ..          ...         ...               ...
# 715         100       11.70        light snow
# 716          40       10.36  scattered clouds
# 718         100        3.51   overcast clouds
# 719          86        5.37   overcast clouds
# 720         100       11.23   overcast clouds
#
# [584 rows x 10 columns]

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# YOUR CODE HERE

clean_travel_cities_df = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities_df

#shows the total rows without ".head()" - good to see it dropped rows
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0     byron bay      AU -28.6500  153.6167     79.95        62
# 1          1  punta arenas      CL -53.1500  -70.9167     53.11        37
# 2          2        faanui      PF -16.4833 -151.7500     81.16        58
# 3          3   new norfolk      AU -42.7826  147.0587     72.72        46
# 4          4       cayenne      GF   4.9333  -52.3333     73.44       100
# ..       ...           ...     ...      ...       ...       ...       ...
# 715      715      sobolevo      RU  54.4299   31.8996     30.34        96
# 716      716         dubbo      AU -32.2500  148.6167     80.73        44
# 718      718      purepero      MX  19.9167 -102.0167     64.26        32
# 719      719        kijang      KR  35.2442  129.2139     31.73        25
# 720      720   san quintin      MX  30.4833 -115.9500     60.30        81
#
#      Cloudiness  Wind Speed           Weather
# 0            65        9.46     broken clouds
# 1             0       23.02         clear sky
# 2            97       14.29   overcast clouds
# 3            31        2.98  scattered clouds
# 4            75        0.00     broken clouds
# ..          ...         ...               ...
# 715         100       11.70        light snow
# 716          40       10.36  scattered clouds
# 718         100        3.51   overcast clouds
# 719          86        5.37   overcast clouds
# 720         100       11.23   overcast clouds
#
# [576 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities_df[["City", "Country", "Max Temp", "Weather", "Lat", "Lng"]].copy()
hotel_df
# Out:
#              City Country  Max Temp           Weather      Lat       Lng
# 0       byron bay      AU     79.95     broken clouds -28.6500  153.6167
# 1    punta arenas      CL     53.11         clear sky -53.1500  -70.9167
# 2          faanui      PF     81.16   overcast clouds -16.4833 -151.7500
# 3     new norfolk      AU     72.72  scattered clouds -42.7826  147.0587
# 4         cayenne      GF     73.44     broken clouds   4.9333  -52.3333
# ..            ...     ...       ...               ...      ...       ...
# 715      sobolevo      RU     30.34        light snow  54.4299   31.8996
# 716         dubbo      AU     80.73  scattered clouds -32.2500  148.6167
# 718      purepero      MX     64.26   overcast clouds  19.9167 -102.0167
# 719        kijang      KR     31.73   overcast clouds  35.2442  129.2139
# 720   san quintin      MX     60.30   overcast clouds  30.4833 -115.9500
#
# [576 rows x 6 columns]

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#              City Country  Max Temp           Weather      Lat       Lng  \
# 0       byron bay      AU     79.95     broken clouds -28.6500  153.6167
# 1    punta arenas      CL     53.11         clear sky -53.1500  -70.9167
# 2          faanui      PF     81.16   overcast clouds -16.4833 -151.7500
# 3     new norfolk      AU     72.72  scattered clouds -42.7826  147.0587
# 4         cayenne      GF     73.44     broken clouds   4.9333  -52.3333
# ..            ...     ...       ...               ...      ...       ...
# 715      sobolevo      RU     30.34        light snow  54.4299   31.8996
# 716         dubbo      AU     80.73  scattered clouds -32.2500  148.6167
# 718      purepero      MX     64.26   overcast clouds  19.9167 -102.0167
# 719        kijang      KR     31.73   overcast clouds  35.2442  129.2139
# 720   san quintin      MX     60.30   overcast clouds  30.4833 -115.9500
#
#     Hotel Name
# 0
# 1
# 2
# 3
# 4
# ..         ...
# 715
# 716
# 718
# 719
# 720
#
# [576 rows x 7 columns]

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()


    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# byron bay - nearest hotel: Lord Byron Resort
# punta arenas - nearest hotel: Hotel Lacolet
# faanui - nearest hotel: Oa Oa Lodge
# new norfolk - nearest hotel: Woodbridge on the Derwent
# cayenne - nearest hotel: Central Hôtel
# belmonte - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# vestmanna - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# buraydah - nearest hotel: دنا للوحدات السكنية
# vaini - nearest hotel: Keleti International Resort
# port-cartier - nearest hotel: No hotel found
# hermanus - nearest hotel: Aloe guest house
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# bethel - nearest hotel: Hampton Inn Danbury
# cape town - nearest hotel: Townhouse Hotel
# chuy - nearest hotel: Alerces
# rikitea - nearest hotel: Chez Bianca & Benoit
# shenzhen - nearest hotel: Shenzhen International Elite Hotel
# gorgan - nearest hotel: هتل خیام
# mataura - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# sampit - nearest hotel: Hotel Sultan
# mindelo - nearest hotel: Solar Windelo
# athabasca - nearest hotel: Grand Union Hotel
# brentwood - nearest hotel: Radisson Hotel Hauppauge-Long Island
# ponta do sol - nearest hotel: Estalagem Ponta do Sol
# richards bay - nearest hotel: Protea Hotel
# santa isabel do rio negro - nearest hotel: Hotel Maikon
# hilo - nearest hotel: Dolphin Bay Hotel
# port alfred - nearest hotel: No hotel found
# westport - nearest hotel: Norwalk Inn and Conference Center
# lorengau - nearest hotel: Seeadler Bay Hotel
# bluff - nearest hotel: No hotel found
# saint-philippe - nearest hotel: Le Baril
# grand-santi - nearest hotel: No hotel found
# hobart - nearest hotel: Vibe Hotel Hobart
# olafsvik - nearest hotel: North Star Hotel Snæfellsnes
# itarema - nearest hotel: Pousada Oásis
# kodiak - nearest hotel: Shelikof Lodge
# borba - nearest hotel: No hotel found
# gat - nearest hotel: No hotel found
# castro - nearest hotel: Hotel Central Palace
# biak - nearest hotel: No hotel found
# kudahuvadhoo - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# hasaki - nearest hotel: 大新旅館
# bredasdorp - nearest hotel: Victoria Hotel
# arraial do cabo - nearest hotel: No hotel found
# camacha - nearest hotel: Praia Dourada
# pandan - nearest hotel: No hotel found
# garowe - nearest hotel: Red Sea
# puri - nearest hotel: Divine Beach Homestay
# klaksvik - nearest hotel: Hotel Klaksvik
# port macquarie - nearest hotel: The Observatory
# kapaa - nearest hotel: Pono Kai Resort
# dingle - nearest hotel: No hotel found
# channel-port aux basques - nearest hotel: St. Christopher's Hotel
# ilhabela - nearest hotel: Vila Kebaya
# coahuayana - nearest hotel: No hotel found
# poum - nearest hotel: No hotel found
# groningen - nearest hotel: No hotel found
# tual - nearest hotel: Suita
# mahebourg - nearest hotel: Grand Bel Air
# kihei - nearest hotel: Maui Beach Resort
# bandarbeyla - nearest hotel: No hotel found
# atuona - nearest hotel: Pearl Resort
# baherden - nearest hotel: No hotel found
# abu kamal - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# oneonta - nearest hotel: Courtyard by Marriott Oneonta
# jamestown - nearest hotel: DoubleTree Jamestown
# san policarpo - nearest hotel: No hotel found
# souillac - nearest hotel: Hotel SkylineInn
# corrales - nearest hotel: Days Inn by Wyndham Rio Rancho
# pisco - nearest hotel: La Portada
# mikhaylovka - nearest hotel: Дружба
# isangel - nearest hotel: Tanna Lodge
# coihaique - nearest hotel: No hotel found
# marfino - nearest hotel: Можайская
# comodoro rivadavia - nearest hotel: No hotel found
# bathsheba - nearest hotel: Atlantis Hotel
# temerloh - nearest hotel: Hotel Jelai
# busselton - nearest hotel: No hotel found
# plettenberg bay - nearest hotel: Milkwood Manor
# tanout - nearest hotel: No hotel found
# marshall - nearest hotel: No hotel found
# sorland - nearest hotel: Fagmek Resorts
# quarai - nearest hotel: Hotel União
# touros - nearest hotel: Pousada Atlântico
# mar del plata - nearest hotel: Nuevo Ostende
# nabire - nearest hotel: Hotel Anggrek
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# airai - nearest hotel: No hotel found
# mexico - nearest hotel: Buena Amore Hotel
# norden - nearest hotel: Hotel Ostfriesland
# saint-augustin - nearest hotel: No hotel found
# dubuque - nearest hotel: American Inn and Suites
# hun - nearest hotel: فندق الهروج
# grand gaube - nearest hotel: Coco Villa
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# elizabeth city - nearest hotel: Quality Inn
# salta - nearest hotel: Ayres de Salta Hotel
# hithadhoo - nearest hotel: Pebbles Inn
# ahipara - nearest hotel: YHA Ahipara
# kouroussa - nearest hotel: No hotel found
# salalah - nearest hotel: Muscat International Hotel
# maragogi - nearest hotel: Pousada Mariluz
# pacific grove - nearest hotel: Pacific Grove Inn
# anapskaya - nearest hotel: Red Hotel
# hurghada - nearest hotel: Sea Horse Hotel
# ronne - nearest hotel: Det gamle posthus
# kosai - nearest hotel: ルートイン
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# kruisfontein - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# kaitangata - nearest hotel: No hotel found
# northam - nearest hotel: Durrant House Hotel
# saint george - nearest hotel: The Advenire, an Autograph Collection Hotel
# tefe - nearest hotel: Hotel Montecarlo
# ostrovnoy - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# havre-saint-pierre - nearest hotel: Complexe MV
# manaus - nearest hotel: No hotel found
# cockburn town - nearest hotel: The Salt Raker Inn
# klupci - nearest hotel: Stobex
# akdepe - nearest hotel: No hotel found
# gibara - nearest hotel: Plaza Colón
# margate - nearest hotel: The Reading Rooms
# meadow lake - nearest hotel: No hotel found
# nanakuli - nearest hotel: No hotel found
# palmer - nearest hotel: No hotel found
# kahului - nearest hotel: Maui Seaside Hotel
# subcetate - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# killybegs - nearest hotel: Bay View Hotel
# kutum - nearest hotel: No hotel found
# beloha - nearest hotel: No hotel found
# japura - nearest hotel: No hotel found
# puerto palomas - nearest hotel: No hotel found
# port hardy - nearest hotel: No hotel found
# lakheri - nearest hotel: No hotel found
# palmas - nearest hotel: Hotel Triângulo Mineiro
# lima - nearest hotel: Hotel Peach Garden
# la paz - nearest hotel: Alojamiento Tokio
# cortes - nearest hotel: Casa rural El Talon del Rey
# koulikoro - nearest hotel: No hotel found
# kenai - nearest hotel: Beluga Lookout Hotel
# rognan - nearest hotel: Rognan hotell
# tucuman - nearest hotel: Suites San Luis
# russell - nearest hotel: No hotel found
# bayir - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# salas - nearest hotel: Castillo de Valdés-Salas
# ugoofaaru - nearest hotel: No hotel found
# guerrero negro - nearest hotel: Plaza sal paraiso
# bara - nearest hotel: No hotel found
# cabedelo - nearest hotel: No hotel found
# benguela - nearest hotel: Hotel Moibela
# aquiraz - nearest hotel: Pousada tia Fabíola
# ponta delgada - nearest hotel: Hotel Talisman
# raga - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# khvoynaya - nearest hotel: Гостиница (2й этаж)
# torbay - nearest hotel: No hotel found
# bosaso - nearest hotel: Bosaso hotel
# bengkulu - nearest hotel: Dena Hotel
# havoysund - nearest hotel: Havøysund Hotell
# saint-pierre - nearest hotel: Tropic Hotel
# lachhmangarh - nearest hotel: No hotel found
# cetraro - nearest hotel: No hotel found
# santa rosa - nearest hotel: JARS RESORT
# ankang - nearest hotel: 金友商务酒店
# bambanglipuro - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# andilamena - nearest hotel: Hotely Magic
# morros - nearest hotel: No hotel found
# bambous virieux - nearest hotel: No hotel found
# arvika - nearest hotel: Jennys Hotell och restaurang
# huarmey - nearest hotel: Hostal Santa Rosa
# libertador general san martin - nearest hotel: Hosteria Real Victoria
# kwinana - nearest hotel: No hotel found
# avera - nearest hotel: No hotel found
# pontianak - nearest hotel: Golden Tulip Hotel
# panalingaan - nearest hotel: No hotel found
# iisalmi - nearest hotel: Original Sokos Hotel Koljonvirta
# ixtapa - nearest hotel: No hotel found
# kulhudhuffushi - nearest hotel: No hotel found
# choszczno - nearest hotel: Hostel
# maningrida - nearest hotel: No hotel found
# tuatapere - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# sauce - nearest hotel: No hotel found
# nichinan - nearest hotel: No hotel found
# lagos - nearest hotel: No hotel found
# lira - nearest hotel: Pauline Hotel
# kjollefjord - nearest hotel: Hotel Nordkyn
# manta - nearest hotel: La Gaviota
# marawi - nearest hotel: Marawi Resort Hotel
# ribeira grande - nearest hotel: No hotel found
# kuala terengganu - nearest hotel: Uncle Homestay
# houma - nearest hotel: Courtyard by Marriott Houma
# kirakira - nearest hotel: No hotel found
# acarau - nearest hotel: No hotel found
# nagyrabe - nearest hotel: No hotel found
# hualmay - nearest hotel: Hotel Mi Choacan
# asyut - nearest hotel: فندق الحسين
# merauke - nearest hotel: No hotel found
# grand bank - nearest hotel: No hotel found
# hojslev - nearest hotel: No hotel found
# victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# quatre cocos - nearest hotel: Horisun
# taoudenni - nearest hotel: No hotel found
# maceio - nearest hotel: Maceió Hostel e Pousada
# nikolskoye - nearest hotel: No hotel found
# labuhan - nearest hotel: No hotel found
# broome - nearest hotel: No hotel found
# ballina - nearest hotel: Ballina Beach Resort
# concepcion del oro - nearest hotel: No hotel found
# cam ranh - nearest hotel: Khách sạn Thái Bình
# pedernales - nearest hotel: Hostal Doña Chava
# cabo san lucas - nearest hotel: Comfort Rooms
# caravelas - nearest hotel: Pousada dos Navegantes
# baoning - nearest hotel: No hotel found
# sao filipe - nearest hotel: Bela Vista
# lagoa - nearest hotel: Casa da Madrinha
# butaritari - nearest hotel: No hotel found
# bardiyah - nearest hotel: فندق البردي
# peace river - nearest hotel: New Ridge Inn
# chimbote - nearest hotel: Hostal Diamante Chimbote
# winsum - nearest hotel: Bedstee hotel Marenland
# xinzhi - nearest hotel: No hotel found
# buerarema - nearest hotel: No hotel found
# bonito - nearest hotel: Hotel Pousada Arauna
# uruzgan - nearest hotel: No hotel found
# port-gentil - nearest hotel: Tara-Mé
# husavik - nearest hotel: Fosshótel Húsavík
# carnarvon - nearest hotel: No hotel found
# kiunga - nearest hotel: No hotel found
# san fernando - nearest hotel: Pampanga Lodge and Restaurant
# lewiston - nearest hotel: Hampton
# cidreira - nearest hotel: Hotel Castelo
# chateaudun - nearest hotel: Ibis Budget Chateaudun
# kanye - nearest hotel: No hotel found
# kidal - nearest hotel: No hotel found
# bhubaneswar - nearest hotel: Airport Park Villa
# sechura - nearest hotel: Hospedaje Claritza
# itoman - nearest hotel: No hotel found
# haines junction - nearest hotel: Parkside Inn
# jambi - nearest hotel: Hotel Odua Weston Jambi
# antofagasta - nearest hotel: Hotel Colón
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# broken hill - nearest hotel: Ibis Styles
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# mabaruma - nearest hotel: Monty Brooms Hotel
# pierre - nearest hotel: Quality Inn
# rauma - nearest hotel: Hotelli Vanha Rauma
# lata - nearest hotel: No hotel found
# laurel - nearest hotel: Quality Inn & Suites
# spalene porici - nearest hotel: Hotel Pod Kokšínem
# williamsburg - nearest hotel: Fife & Drum Inn Suites
# quchan - nearest hotel: هتل خیام
# lusaka - nearest hotel: Lusaka Grand Hotel
# shelburne - nearest hotel: No hotel found
# saint-francois - nearest hotel: No hotel found
# panama city - nearest hotel: Hostal Familiar Carmencita
# altagracia de orituco - nearest hotel: Hotel El Canastro
# nago - nearest hotel: 白浜
# la mira - nearest hotel: No hotel found
# paita - nearest hotel: Victor's
# karratha - nearest hotel: Karratha International Hotel
# acuitzio - nearest hotel: No hotel found
# bonham - nearest hotel: Holiday Inn
# saint paul - nearest hotel: Crowne Plaza
# chingola - nearest hotel: Protea Hotel
# adrar - nearest hotel: No hotel found
# montepuez - nearest hotel: Complexo Messalo
# joacaba - nearest hotel: Hotel Jaraguá
# kieta - nearest hotel: No hotel found
# nouadhibou - nearest hotel: Hotel valencia
# kendari - nearest hotel: City Hotel Kendari
# jeremie - nearest hotel: Delivrance Hotel
# coquimbo - nearest hotel: Hotel Iberia
# mehamn - nearest hotel: Mehamn Arctic hotell
# ancud - nearest hotel: Cabañas
# kontagora - nearest hotel: No hotel found
# samarai - nearest hotel: No hotel found
# port hedland - nearest hotel: The Esplanade Hotel
# dawei - nearest hotel: Royal Dawei ဟိုတယ်
# serchhip - nearest hotel: No hotel found
# berlevag - nearest hotel: No hotel found
# portland - nearest hotel: the Hoxton
# severo-kurilsk - nearest hotel: "Дом рыбака"
# balingasay - nearest hotel: Ramos Beach Resort
# port hueneme - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# mareeba - nearest hotel: The Gateway Hotel
# hervey bay - nearest hotel: Hervey Bay Hotel
# puro - nearest hotel: No hotel found
# vardo - nearest hotel: Meieriet
# jackson - nearest hotel: Brookside
# marsabit - nearest hotel: Chicho Hotel
# farah - nearest hotel: No hotel found
# quelimane - nearest hotel: Mabassa
# nemuro - nearest hotel: イーストハーバーホテル
# dumbraveni - nearest hotel: Hotel Mario
# laguna - nearest hotel: Holiday Inn Express & Suites
# sorong - nearest hotel: Hotel Membramo Marina
# riyadh - nearest hotel: White Palace Hotel
# gulu - nearest hotel: No hotel found
# taperoa - nearest hotel: Hotel Casarão
# clovis - nearest hotel: BEST WESTERN Clovis Cole
# tautira - nearest hotel: No hotel found
# paea - nearest hotel: Taaroa Lodge
# parana - nearest hotel: Grand Hotel Alvear
# belaya glina - nearest hotel: Нива
# starkville - nearest hotel: Days Inn
# hansot - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# north bend - nearest hotel: The Mill Casino Hotel
# oliver - nearest hotel: Coast Oliver Hotel
# nishihara - nearest hotel: ユインチホテル南城
# sumbe - nearest hotel: No hotel found
# les cayes - nearest hotel: No hotel found
# taltal - nearest hotel: Hostería Taltal
# dinguiraye - nearest hotel: No hotel found
# abengourou - nearest hotel: Relief
# tabou - nearest hotel: hôtel le rochet
# nyimba - nearest hotel: Dalitso Guesthouse
# moussoro - nearest hotel: No hotel found
# basqal - nearest hotel: No hotel found
# san cristobal - nearest hotel: Terra Sur
# jatai - nearest hotel: Hotel Rio Claro
# quang ngai - nearest hotel: Ngoc Anh
# krasnoarmeyskiy - nearest hotel: No hotel found
# soavinandriana - nearest hotel: No hotel found
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# hasuda - nearest hotel: むさしのグランドホテル&スパ
# sterling - nearest hotel: Residence Inn by Marriott Dulles Airport at Dulles 28 Centre
# masterton - nearest hotel: Copthorne Hotel Solway Park
# buin - nearest hotel: No hotel found
# hofn - nearest hotel: Guesthouse Dyngja
# matay - nearest hotel: No hotel found
# havelock - nearest hotel: Quality Inn Havelock Hwy 70
# santiago del estero - nearest hotel: Nuevo Hotel Brístol
# baylo - nearest hotel: No hotel found
# charters towers - nearest hotel: No hotel found
# te anau - nearest hotel: Lakeside Motels & Apartments
# ilinskiy - nearest hotel: Зодиак
# dargaville - nearest hotel: Central Hotel
# srisailam - nearest hotel: No hotel found
# smithfield - nearest hotel: Holiday Inn Express & Suites Smithfield
# naivasha - nearest hotel: Supa Lodge
# harper - nearest hotel: No hotel found
# alofi - nearest hotel: No hotel found
# amalapuram - nearest hotel: No hotel found
# cururupu - nearest hotel: No hotel found
# syracuse - nearest hotel: Hotel Panorama
# malakal - nearest hotel: No hotel found
# werda - nearest hotel: No hotel found
# alcudia - nearest hotel: Can Mostatxins
# grindavik - nearest hotel: The Retreat at Blue Lagoon Iceland
# namatanai - nearest hotel: Namatanai Hotel
# jumla - nearest hotel: Amar Sandesh Guesthouse
# ayorou - nearest hotel: Hotel Aminokal
# zhanaozen - nearest hotel: No hotel found
# sept-iles - nearest hotel: Château Arnaud
# hisar - nearest hotel: OYO Mid City Hotel
# moberly - nearest hotel: Super 8 by Wyndham Moberly MO
# lithgow - nearest hotel: Grand Central Hotel
# kerema - nearest hotel: No hotel found
# itaobim - nearest hotel: No hotel found
# tibati - nearest hotel: No hotel found
# gloversville - nearest hotel: Holiday Inn
# kalmunai - nearest hotel: Saji new food
# shimoda - nearest hotel: ホテルウラガ
# constitucion - nearest hotel: Hostal Alameda
# paris - nearest hotel: Hôtel Esmerelda
# canmore - nearest hotel: Mountain View Inn
# sambava - nearest hotel: Royal Sava Hôtel
# alyangula - nearest hotel: No hotel found
# ouegoa - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# myingyan - nearest hotel: No hotel found
# kosmynino - nearest hotel: No hotel found
# wattegama - nearest hotel: No hotel found
# angoche - nearest hotel: Hotel Quirimbas
# aitape - nearest hotel: No hotel found
# asau - nearest hotel: No hotel found
# yeppoon - nearest hotel: Blossom's on Seaspray
# ndjole - nearest hotel: Motel Kedyann
# tabuk - nearest hotel: Davidson Hotel
# pasni - nearest hotel: No hotel found
# jalu - nearest hotel: فندق جالو السياحي
# katsuura - nearest hotel: 潮騒の宿
# ilihan - nearest hotel: No hotel found
# kupang - nearest hotel: BIB & LANG GUEST HOUSE
# atar - nearest hotel: فندق سكليل
# mtambile - nearest hotel: No hotel found
# escanaba - nearest hotel: Magnuson Grand Pioneer Inn and Suites
# pitimbu - nearest hotel: Pousada Brisa Mar
# vallenar - nearest hotel: Hotel del Marqués
# santa fe - nearest hotel: Intersur Hotel
# mandera - nearest hotel: Kornesh Hotel and Lodging
# the valley - nearest hotel: CeBlue
# saint peter - nearest hotel: Ancient Grove
# kisangani - nearest hotel: Le Chalet
# kavieng - nearest hotel: Kavieng Hotel
# sukhumi - nearest hotel: Монэ
# pabrade - nearest hotel: No hotel found
# casper - nearest hotel: Days Inn by Wyndham Casper
# lakes entrance - nearest hotel: Banjo Patterson Motor Inn
# porangatu - nearest hotel: No hotel found
# wasilla - nearest hotel: No hotel found
# liberal - nearest hotel: Days Inn
# porto santo - nearest hotel: Praia Dourada
# williams lake - nearest hotel: Coast Fraser Inn
# kloulklubed - nearest hotel: The Adventures Inn
# codrington - nearest hotel: No hotel found
# trelew - nearest hotel: Patagonia Suites & Apart
# marystown - nearest hotel: Marystown Hotel & Convention Centre
# musoma - nearest hotel: New Peninsula Hotel
# oeiras do para - nearest hotel: No hotel found
# ahuimanu - nearest hotel: No hotel found
# coffeyville - nearest hotel: No hotel found
# mahajanga - nearest hotel: Vahiny Hotel
# oksfjord - nearest hotel: No hotel found
# ocala - nearest hotel: Hilton Garden Inn
# pinawa - nearest hotel: Pinawa Motor Inn
# kibala - nearest hotel: No hotel found
# navsari - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# mayumba - nearest hotel: Résidence Hôtelière Fabso
# otane - nearest hotel: No hotel found
# doka - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# gladstone - nearest hotel: Gladstone Downtown Central
# aksum - nearest hotel: Delina Hotel
# georgetown - nearest hotel: Page 63 hostel
# aspindza - nearest hotel: Atas Erti Ghame
# iwaki - nearest hotel: Iwaki Prince Hotel
# sfantu gheorghe - nearest hotel: Hotel Park
# almenara - nearest hotel: No hotel found
# copiapo - nearest hotel: Hotel Il Riposo
# rocha - nearest hotel: Hotel Municipal
# yashkul - nearest hotel: No hotel found
# cahors - nearest hotel: No hotel found
# nizwa - nearest hotel: Nizwa Heritage Inn
# damaturu - nearest hotel: No hotel found
# inongo - nearest hotel: Chez LELE IYOLO
# vangaindrano - nearest hotel: Fanilo
# gamba - nearest hotel: No hotel found
# esperance - nearest hotel: Hospitality
# irondequoit - nearest hotel: Hampton
# nong ki - nearest hotel: resort
# mogadishu - nearest hotel: SYL Hotel
# kesova gora - nearest hotel: Гостиница Кесова Гора
# tongren - nearest hotel: 闽 商大 酒 店
# along - nearest hotel: Hotel Toshi Palace
# san juan - nearest hotel: Hotel San Francisco
# fairmont - nearest hotel: Clarion Inn
# xinxiang - nearest hotel: 凯悦酒店
# lodwar - nearest hotel: Lodwar Modern Lodge
# yanliang - nearest hotel: Jinjiang
# craig - nearest hotel: Quality Inn & Suites
# eldorado - nearest hotel: Hotel Laçador
# deyang - nearest hotel: 怡家丽景酒店
# sitka - nearest hotel: Aspen Suites Hotel
# awjilah - nearest hotel: No hotel found
# hachinohe - nearest hotel: スーパーホテル
# peniche - nearest hotel: Residencial Maciel
# neftekumsk - nearest hotel: No hotel found
# biltine - nearest hotel: فندق ثلاث نجوم بلتن
# banda aceh - nearest hotel: Hotel 61
# gushikawa - nearest hotel: No hotel found
# bundaberg - nearest hotel: Young Australian Hotel
# redlands - nearest hotel: Ayres Hotel Redlands
# bismarck - nearest hotel: Radisson Hotel Bismarck
# kauhajoki - nearest hotel: Kauhajoen Krouvi
# sarangani - nearest hotel: No hotel found
# calabozo - nearest hotel: Hotel Plaza Real
# moerai - nearest hotel: Manotel Rurutu
# drexel heights - nearest hotel: No hotel found
# vao - nearest hotel: Nataiwatch
# launceston - nearest hotel: Hotel Charles
# carutapera - nearest hotel: No hotel found
# morondava - nearest hotel: Hotel Sharon Menabe
# kuah - nearest hotel: Langkawi Budget Inn
# palmerston - nearest hotel: No hotel found
# akom - nearest hotel: No hotel found
# port blair - nearest hotel: Andaman Ocean Breeze
# vilhena - nearest hotel: No hotel found
# raudeberg - nearest hotel: No hotel found
# half moon bay - nearest hotel: Half Moon Bay Inn
# boksitogorsk - nearest hotel: Металлург
# moose factory - nearest hotel: Cree Village Ecolodge
# gonbad-e qabus - nearest hotel: هتل قابوس
# nanyuki - nearest hotel: Ibis Hotel
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# erzin - nearest hotel: No hotel found
# ikungi - nearest hotel: Safina Lodge
# panguna - nearest hotel: No hotel found
# boende - nearest hotel: No hotel found
# los llanos de aridane - nearest hotel: Valle Aridane
# svetlyy - nearest hotel: No hotel found
# fonte boa - nearest hotel: No hotel found
# alfenas - nearest hotel: Hotel JS
# ouallam - nearest hotel: No hotel found
# muros - nearest hotel: Pensión Ría de Muros
# hong gai - nearest hotel: Koc moc
# marsh harbour - nearest hotel: Lofty Fig Villas
# coffs harbour - nearest hotel: The Coast Hotel
# eureka - nearest hotel: Eureka Inn, Trademark Collection by Wyndham
# saint-leu - nearest hotel: Iloha Seaview Hôtel
# saint anthony - nearest hotel: Delta Hotels by Marriott
# bay roberts - nearest hotel: No hotel found
# tiarei - nearest hotel: No hotel found
# nova bystrice - nearest hotel: Hotel Fogl
# namibe - nearest hotel: Hotel Chik Chik Namibe
# mwense - nearest hotel: No hotel found
# sioux lookout - nearest hotel: Wellington Inn & Restaurant
# qingquan - nearest hotel: No hotel found
# moron - nearest hotel: La Esquina
# kuryk - nearest hotel: Kuryk
# pangkalanbuun - nearest hotel: Hotel Tiara
# abnub - nearest hotel: No hotel found
# boundiali - nearest hotel: No hotel found
# xiangxiang - nearest hotel: No hotel found
# luau - nearest hotel: No hotel found
# boyolangu - nearest hotel: No hotel found
# aberdeen - nearest hotel: Jurys Inn
# soyo - nearest hotel: Hotel Maria Teres
# tudela - nearest hotel: Hostal Remigio
# kita - nearest hotel: Hotel Chats Rouges
# banjar - nearest hotel: Villa Banjar Beach
# jacareacanga - nearest hotel: Hotel São Cristovão
# arlit - nearest hotel: No hotel found
# whitianga - nearest hotel: No hotel found
# pokhara - nearest hotel: Hotel Annapurna View Sarangkot
# tanete - nearest hotel: Hotel grand Sidny
# khani - nearest hotel: No hotel found
# dhidhdhoo - nearest hotel: No hotel found
# lasa - nearest hotel: Hotel "Drei Kreuz"
# nanning - nearest hotel: No hotel found
# codajas - nearest hotel: No hotel found
# campbell river - nearest hotel: Comfort Inn & Suites
# maumere - nearest hotel: Bogor
# ouadda - nearest hotel: No hotel found
# karoi - nearest hotel: The Champion Lodge
# sistranda - nearest hotel: Hotell Frøya
# yazman - nearest hotel: Yazman Banquet Marriage Hall
# goderich - nearest hotel: Hotel Bedford
# skjervoy - nearest hotel: Hotel Maritim Skjervøy
# fort-shevchenko - nearest hotel: Akku
# ushibuka - nearest hotel: Hotel Harbor Inn
# sao miguel do tapuio - nearest hotel: No hotel found
# xalpatlahuac - nearest hotel: No hotel found
# deniliquin - nearest hotel: No hotel found
# maneadero - nearest hotel: No hotel found
# arona - nearest hotel: Hotel Rural La Correa
# kumluca - nearest hotel: No hotel found
# laguna de perlas - nearest hotel: Hotelito Bella Vista;Western Union
# monfalcone - nearest hotel: Hotel al gelso
# sola - nearest hotel: No hotel found
# new bern - nearest hotel: DoubleTree by Hilton
# oussouye - nearest hotel: Campement Alulum
# boca do acre - nearest hotel: No hotel found
# sheopur - nearest hotel: No hotel found
# sur - nearest hotel: Sur Hotel
# altamont - nearest hotel: Quality Inn
# sobolevo - nearest hotel: No hotel found
# dubbo - nearest hotel: Blue Gum Motel
# purepero - nearest hotel: No hotel found
# kijang - nearest hotel: No hotel found
# san quintin - nearest hotel: Jardines Hotel
#              City Country  Max Temp           Weather      Lat       Lng  \
# 0       byron bay      AU     79.95     broken clouds -28.6500  153.6167
# 1    punta arenas      CL     53.11         clear sky -53.1500  -70.9167
# 2          faanui      PF     81.16   overcast clouds -16.4833 -151.7500
# 3     new norfolk      AU     72.72  scattered clouds -42.7826  147.0587
# 4         cayenne      GF     73.44     broken clouds   4.9333  -52.3333
# ..            ...     ...       ...               ...      ...       ...
# 715      sobolevo      RU     30.34        light snow  54.4299   31.8996
# 716         dubbo      AU     80.73  scattered clouds -32.2500  148.6167
# 718      purepero      MX     64.26   overcast clouds  19.9167 -102.0167
# 719        kijang      KR     31.73   overcast clouds  35.2442  129.2139
# 720   san quintin      MX     60.30   overcast clouds  30.4833 -115.9500
#
#                     Hotel Name
# 0            Lord Byron Resort
# 1                Hotel Lacolet
# 2                  Oa Oa Lodge
# 3    Woodbridge on the Derwent
# 4                Central Hôtel
# ..                         ...
# 715             No hotel found
# 716             Blue Gum Motel
# 718             No hotel found
# 719             No hotel found
# 720             Jardines Hotel
#
# [576 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df
# Out:
#              City Country  Max Temp           Weather      Lat       Lng  \
# 0       byron bay      AU     79.95     broken clouds -28.6500  153.6167
# 1    punta arenas      CL     53.11         clear sky -53.1500  -70.9167
# 2          faanui      PF     81.16   overcast clouds -16.4833 -151.7500
# 3     new norfolk      AU     72.72  scattered clouds -42.7826  147.0587
# 4         cayenne      GF     73.44     broken clouds   4.9333  -52.3333
# ..            ...     ...       ...               ...      ...       ...
# 710      oussouye      SN     72.12     broken clouds  12.4850  -16.5469
# 713           sur      OM     67.55  scattered clouds  22.5667   59.5289
# 714      altamont      US     38.89         clear sky  42.2068 -121.7372
# 716         dubbo      AU     80.73  scattered clouds -32.2500  148.6167
# 720   san quintin      MX     60.30   overcast clouds  30.4833 -115.9500
#
#                     Hotel Name
# 0            Lord Byron Resort
# 1                Hotel Lacolet
# 2                  Oa Oa Lodge
# 3    Woodbridge on the Derwent
# 4                Central Hôtel
# ..                         ...
# 710           Campement Alulum
# 713                  Sur Hotel
# 714                Quality Inn
# 716             Blue Gum Motel
# 720             Jardines Hotel
#
# [373 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
clean_hotel_df.to_csv("WeatherPy_vacation.csv", index_label="City_ID")

# Export the City_Data into a csv
# YOUR CODE HERE

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Weather", "Country", "Hotel Name"])

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Weather,Country,Hotel Name)
