# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 787

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]    
        
        #city_weather_description needs the brackets and 0 b/c it is a list, unlike the others which are just dictionaries
        
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | byron bay
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | cayenne
# Processing Record 6 of Set 1 | ust-nera
# Processing Record 7 of Set 1 | belmonte
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | vestmanna
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | buraydah
# Processing Record 12 of Set 1 | beringovskiy
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | port-cartier
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | egvekinot
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | sisimiut
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | shenzhen
# Processing Record 27 of Set 1 | gorgan
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | macamic
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | ust-kuyga
# Processing Record 33 of Set 1 | sampit
# Processing Record 34 of Set 1 | mindelo
# Processing Record 35 of Set 1 | athabasca
# Processing Record 36 of Set 1 | brentwood
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | richards bay
# Processing Record 39 of Set 1 | santa isabel do rio negro
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | westport
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | grand-santi
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | olafsvik
# Processing Record 1 of Set 2 | itarema
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | borba
# Processing Record 4 of Set 2 | gat
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | teya
# Processing Record 7 of Set 2 | biak
# Processing Record 8 of Set 2 | kudahuvadhoo
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | camacha
# Processing Record 15 of Set 2 | pandan
# Processing Record 16 of Set 2 | garowe
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | puri
# Processing Record 19 of Set 2 | belaya gora
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | port macquarie
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | aykhal
# Processing Record 25 of Set 2 | dingle
# Processing Record 26 of Set 2 | channel-port aux basques
# Processing Record 27 of Set 2 | ilhabela
# Processing Record 28 of Set 2 | coahuayana
# Processing Record 29 of Set 2 | poum
# Processing Record 30 of Set 2 | groningen
# Processing Record 31 of Set 2 | tual
# Processing Record 32 of Set 2 | deputatskiy
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | kihei
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | baherden
# Processing Record 39 of Set 2 | abu kamal
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | oneonta
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | san policarpo
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | corrales
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | mikhaylovka
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | marfino
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | temerloh
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | plettenberg bay
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | serebryansk
# Processing Record 9 of Set 3 | tanout
# Processing Record 10 of Set 3 | marshall
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | quarai
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | nabire
# Processing Record 16 of Set 3 | rio gallegos
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | mexico
# Processing Record 20 of Set 3 | norden
# Processing Record 21 of Set 3 | kungurtug
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | saint-augustin
# Processing Record 24 of Set 3 | alihe
# Processing Record 25 of Set 3 | dubuque
# Processing Record 26 of Set 3 | hun
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | navoloki
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | champerico
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | elizabeth city
# Processing Record 33 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 3 | salta
# Processing Record 35 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | kouroussa
# Processing Record 39 of Set 3 | mariental
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | maragogi
# Processing Record 42 of Set 3 | pacific grove
# Processing Record 43 of Set 3 | anapskaya
# Processing Record 44 of Set 3 | hurghada
# Processing Record 45 of Set 3 | mokhsogollokh
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | ronne
# Processing Record 48 of Set 3 | kosai
# Processing Record 49 of Set 3 | mount gambier
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | shingu
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | dudinka
# Processing Record 10 of Set 4 | tefe
# Processing Record 11 of Set 4 | songjianghe
# Processing Record 12 of Set 4 | ostrovnoy
# Processing Record 13 of Set 4 | ho
# City not found. Skipping...
# Processing Record 14 of Set 4 | bonthe
# Processing Record 15 of Set 4 | havre-saint-pierre
# Processing Record 16 of Set 4 | manaus
# Processing Record 17 of Set 4 | cockburn town
# Processing Record 18 of Set 4 | klupci
# Processing Record 19 of Set 4 | akdepe
# Processing Record 20 of Set 4 | gibara
# Processing Record 21 of Set 4 | khasan
# Processing Record 22 of Set 4 | margate
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | meadow lake
# Processing Record 26 of Set 4 | nanakuli
# Processing Record 27 of Set 4 | palmer
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | subcetate
# Processing Record 30 of Set 4 | kurilsk
# Processing Record 31 of Set 4 | hamilton
# Processing Record 32 of Set 4 | killybegs
# Processing Record 33 of Set 4 | kutum
# Processing Record 34 of Set 4 | beloha
# Processing Record 35 of Set 4 | ornskoldsvik
# Processing Record 36 of Set 4 | japura
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | puerto palomas
# Processing Record 39 of Set 4 | zhigansk
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | lakheri
# Processing Record 42 of Set 4 | palmas
# Processing Record 43 of Set 4 | lima
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | la paz
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | cortes
# Processing Record 49 of Set 4 | koulikoro
# Processing Record 50 of Set 4 | atbasar
# Processing Record 1 of Set 5 | kenai
# Processing Record 2 of Set 5 | sosnovo-ozerskoye
# Processing Record 3 of Set 5 | zyryanka
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | rognan
# Processing Record 6 of Set 5 | tucuman
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | russell
# Processing Record 9 of Set 5 | bayir
# Processing Record 10 of Set 5 | qaqortoq
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | salas
# Processing Record 13 of Set 5 | ugoofaaru
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | fairbanks
# Processing Record 16 of Set 5 | guerrero negro
# Processing Record 17 of Set 5 | bara
# Processing Record 18 of Set 5 | cabedelo
# Processing Record 19 of Set 5 | benguela
# Processing Record 20 of Set 5 | aquiraz
# Processing Record 21 of Set 5 | ponta delgada
# Processing Record 22 of Set 5 | a
# City not found. Skipping...
# Processing Record 23 of Set 5 | henties bay
# Processing Record 24 of Set 5 | raga
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | khvoynaya
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | bosaso
# Processing Record 30 of Set 5 | urumqi
# Processing Record 31 of Set 5 | bengkulu
# Processing Record 32 of Set 5 | havoysund
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | lachhmangarh
# Processing Record 35 of Set 5 | cetraro
# Processing Record 36 of Set 5 | shelabolikha
# Processing Record 37 of Set 5 | santa rosa
# Processing Record 38 of Set 5 | ankang
# Processing Record 39 of Set 5 | bambanglipuro
# Processing Record 40 of Set 5 | arman
# Processing Record 41 of Set 5 | alice springs
# Processing Record 42 of Set 5 | andilamena
# Processing Record 43 of Set 5 | morros
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | arvika
# Processing Record 46 of Set 5 | lermontovka
# Processing Record 47 of Set 5 | huarmey
# Processing Record 48 of Set 5 | libertador general san martin
# Processing Record 49 of Set 5 | kwinana
# Processing Record 50 of Set 5 | avera
# Processing Record 1 of Set 6 | pontianak
# Processing Record 2 of Set 6 | panalingaan
# Processing Record 3 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 4 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 5 of Set 6 | iisalmi
# Processing Record 6 of Set 6 | ixtapa
# Processing Record 7 of Set 6 | kulhudhuffushi
# Processing Record 8 of Set 6 | choszczno
# Processing Record 9 of Set 6 | maningrida
# Processing Record 10 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | port elizabeth
# Processing Record 14 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | sauce
# Processing Record 17 of Set 6 | nichinan
# Processing Record 18 of Set 6 | teguldet
# Processing Record 19 of Set 6 | lagos
# Processing Record 20 of Set 6 | lira
# Processing Record 21 of Set 6 | kjollefjord
# Processing Record 22 of Set 6 | manta
# Processing Record 23 of Set 6 | marawi
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | ribeira grande
# Processing Record 26 of Set 6 | kuala terengganu
# Processing Record 27 of Set 6 | houma
# Processing Record 28 of Set 6 | kirakira
# Processing Record 29 of Set 6 | acarau
# Processing Record 30 of Set 6 | thompson
# Processing Record 31 of Set 6 | nagyrabe
# Processing Record 32 of Set 6 | hualmay
# Processing Record 33 of Set 6 | asyut
# Processing Record 34 of Set 6 | merauke
# Processing Record 35 of Set 6 | grand bank
# Processing Record 36 of Set 6 | hojslev
# Processing Record 37 of Set 6 | victoria
# Processing Record 38 of Set 6 | quatre cocos
# Processing Record 39 of Set 6 | taoudenni
# Processing Record 40 of Set 6 | maceio
# Processing Record 41 of Set 6 | nikolskoye
# Processing Record 42 of Set 6 | leh
# Processing Record 43 of Set 6 | labuhan
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | ballina
# Processing Record 46 of Set 6 | concepcion del oro
# Processing Record 47 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 49 of Set 6 | cam ranh
# Processing Record 50 of Set 6 | pedernales
# Processing Record 1 of Set 7 | dauphin
# Processing Record 2 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | caravelas
# Processing Record 5 of Set 7 | baoning
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | nome
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | butaritari
# Processing Record 10 of Set 7 | changji
# Processing Record 11 of Set 7 | bardiyah
# Processing Record 12 of Set 7 | suzun
# Processing Record 13 of Set 7 | peace river
# Processing Record 14 of Set 7 | chimbote
# Processing Record 15 of Set 7 | winsum
# Processing Record 16 of Set 7 | xinzhi
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | buerarema
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | narsaq
# Processing Record 21 of Set 7 | bonito
# Processing Record 22 of Set 7 | uruzgan
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | carnarvon
# Processing Record 26 of Set 7 | kiunga
# Processing Record 27 of Set 7 | serov
# Processing Record 28 of Set 7 | san fernando
# Processing Record 29 of Set 7 | lewiston
# Processing Record 30 of Set 7 | high prairie
# Processing Record 31 of Set 7 | cidreira
# Processing Record 32 of Set 7 | chateaudun
# Processing Record 33 of Set 7 | kanye
# Processing Record 34 of Set 7 | kidal
# Processing Record 35 of Set 7 | bhubaneswar
# Processing Record 36 of Set 7 | sechura
# Processing Record 37 of Set 7 | itoman
# Processing Record 38 of Set 7 | kilemary
# Processing Record 39 of Set 7 | haines junction
# Processing Record 40 of Set 7 | jambi
# Processing Record 41 of Set 7 | antofagasta
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | broken hill
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | mabaruma
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | pierre
# Processing Record 48 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 7 | rauma
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | laurel
# Processing Record 2 of Set 8 | spalene porici
# Processing Record 3 of Set 8 | williamsburg
# Processing Record 4 of Set 8 | quchan
# Processing Record 5 of Set 8 | verkhneyarkeyevo
# Processing Record 6 of Set 8 | lusaka
# Processing Record 7 of Set 8 | shelburne
# Processing Record 8 of Set 8 | saint-francois
# Processing Record 9 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 8 | panama city
# Processing Record 11 of Set 8 | altagracia de orituco
# Processing Record 12 of Set 8 | nago
# Processing Record 13 of Set 8 | la mira
# Processing Record 14 of Set 8 | ust-kulom
# Processing Record 15 of Set 8 | paita
# Processing Record 16 of Set 8 | weyburn
# Processing Record 17 of Set 8 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 18 of Set 8 | korla
# Processing Record 19 of Set 8 | karratha
# Processing Record 20 of Set 8 | acuitzio
# Processing Record 21 of Set 8 | bonham
# Processing Record 22 of Set 8 | saint paul
# Processing Record 23 of Set 8 | chingola
# Processing Record 24 of Set 8 | adrar
# Processing Record 25 of Set 8 | montepuez
# Processing Record 26 of Set 8 | upernavik
# Processing Record 27 of Set 8 | joacaba
# Processing Record 28 of Set 8 | kieta
# Processing Record 29 of Set 8 | the pas
# Processing Record 30 of Set 8 | nouadhibou
# Processing Record 31 of Set 8 | kendari
# Processing Record 32 of Set 8 | jeremie
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | at-bashi
# Processing Record 35 of Set 8 | mehamn
# Processing Record 36 of Set 8 | ancud
# Processing Record 37 of Set 8 | kontagora
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | dawei
# Processing Record 41 of Set 8 | peleduy
# Processing Record 42 of Set 8 | serchhip
# Processing Record 43 of Set 8 | berlevag
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | balingasay
# Processing Record 47 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 8 | port hueneme
# Processing Record 49 of Set 8 | saldanha
# Processing Record 50 of Set 8 | mareeba
# Processing Record 1 of Set 9 | bulgan
# Processing Record 2 of Set 9 | hervey bay
# Processing Record 3 of Set 9 | puro
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | jackson
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | marsabit
# Processing Record 8 of Set 9 | farah
# Processing Record 9 of Set 9 | quelimane
# Processing Record 10 of Set 9 | cherepanovo
# Processing Record 11 of Set 9 | aklavik
# Processing Record 12 of Set 9 | nemuro
# Processing Record 13 of Set 9 | dumbraveni
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | hami
# Processing Record 17 of Set 9 | normandin
# Processing Record 18 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 9 | riyadh
# Processing Record 20 of Set 9 | gulu
# Processing Record 21 of Set 9 | ulaanbaatar
# Processing Record 22 of Set 9 | vanavara
# Processing Record 23 of Set 9 | taperoa
# Processing Record 24 of Set 9 | clovis
# Processing Record 25 of Set 9 | tautira
# Processing Record 26 of Set 9 | paea
# Processing Record 27 of Set 9 | parana
# Processing Record 28 of Set 9 | belaya glina
# Processing Record 29 of Set 9 | starkville
# Processing Record 30 of Set 9 | hansot
# Processing Record 31 of Set 9 | luanda
# Processing Record 32 of Set 9 | north bend
# Processing Record 33 of Set 9 | oliver
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | sumbe
# Processing Record 36 of Set 9 | iqaluit
# Processing Record 37 of Set 9 | timra
# Processing Record 38 of Set 9 | les cayes
# Processing Record 39 of Set 9 | taltal
# Processing Record 40 of Set 9 | dinguiraye
# Processing Record 41 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 9 | abengourou
# Processing Record 43 of Set 9 | tabou
# Processing Record 44 of Set 9 | pangody
# Processing Record 45 of Set 9 | nyimba
# Processing Record 46 of Set 9 | moussoro
# Processing Record 47 of Set 9 | basqal
# Processing Record 48 of Set 9 | san cristobal
# Processing Record 49 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 9 | turkistan
# Processing Record 1 of Set 10 | derzhavinsk
# Processing Record 2 of Set 10 | jatai
# Processing Record 3 of Set 10 | quang ngai
# Processing Record 4 of Set 10 | krasnoarmeyskiy
# Processing Record 5 of Set 10 | soavinandriana
# Processing Record 6 of Set 10 | lompoc
# Processing Record 7 of Set 10 | hasuda
# Processing Record 8 of Set 10 | sterling
# Processing Record 9 of Set 10 | masterton
# Processing Record 10 of Set 10 | buin
# Processing Record 11 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 10 | khorixas
# Processing Record 15 of Set 10 | matay
# Processing Record 16 of Set 10 | havelock
# Processing Record 17 of Set 10 | severobaykalsk
# Processing Record 18 of Set 10 | santiago del estero
# Processing Record 19 of Set 10 | baylo
# Processing Record 20 of Set 10 | tigil
# Processing Record 21 of Set 10 | charters towers
# Processing Record 22 of Set 10 | te anau
# Processing Record 23 of Set 10 | ilinskiy
# Processing Record 24 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 10 | yar-sale
# Processing Record 26 of Set 10 | amga
# Processing Record 27 of Set 10 | dargaville
# Processing Record 28 of Set 10 | srisailam
# Processing Record 29 of Set 10 | astana
# Processing Record 30 of Set 10 | smithfield
# Processing Record 31 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 10 | naivasha
# Processing Record 34 of Set 10 | harper
# Processing Record 35 of Set 10 | alofi
# Processing Record 36 of Set 10 | amalapuram
# Processing Record 37 of Set 10 | cururupu
# Processing Record 38 of Set 10 | syracuse
# Processing Record 39 of Set 10 | malakal
# Processing Record 40 of Set 10 | luderitz
# Processing Record 41 of Set 10 | werda
# Processing Record 42 of Set 10 | alcudia
# Processing Record 43 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 10 | grindavik
# Processing Record 45 of Set 10 | namatanai
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | abaza
# Processing Record 48 of Set 10 | ayorou
# Processing Record 49 of Set 10 | zhanaozen
# Processing Record 50 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 11 | sept-iles
# Processing Record 2 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 11 | do rud
# City not found. Skipping...
# Processing Record 4 of Set 11 | hisar
# Processing Record 5 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 11 | aldan
# Processing Record 7 of Set 11 | moberly
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | lithgow
# Processing Record 10 of Set 11 | svetlaya
# Processing Record 11 of Set 11 | kerema
# Processing Record 12 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 11 | itaobim
# Processing Record 14 of Set 11 | ayagoz
# Processing Record 15 of Set 11 | tilichiki
# Processing Record 16 of Set 11 | tibati
# Processing Record 17 of Set 11 | gloversville
# Processing Record 18 of Set 11 | kalmunai
# Processing Record 19 of Set 11 | shimoda
# Processing Record 20 of Set 11 | constitucion
# Processing Record 21 of Set 11 | paris
# Processing Record 22 of Set 11 | canmore
# Processing Record 23 of Set 11 | nyurba
# Processing Record 24 of Set 11 | onguday
# Processing Record 25 of Set 11 | sambava
# Processing Record 26 of Set 11 | alyangula
# Processing Record 27 of Set 11 | ouegoa
# Processing Record 28 of Set 11 | praia da vitoria
# Processing Record 29 of Set 11 | myingyan
# Processing Record 30 of Set 11 | aasiaat
# Processing Record 31 of Set 11 | walvis bay
# Processing Record 32 of Set 11 | privolzhskiy
# Processing Record 33 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 34 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 11 | kosmynino
# Processing Record 36 of Set 11 | wattegama
# Processing Record 37 of Set 11 | angoche
# Processing Record 38 of Set 11 | aitape
# Processing Record 39 of Set 11 | asau
# Processing Record 40 of Set 11 | yeppoon
# Processing Record 41 of Set 11 | ndjole
# Processing Record 42 of Set 11 | tabuk
# Processing Record 43 of Set 11 | pasni
# Processing Record 44 of Set 11 | jalu
# Processing Record 45 of Set 11 | srednekolymsk
# Processing Record 46 of Set 11 | katsuura
# Processing Record 47 of Set 11 | ilihan
# Processing Record 48 of Set 11 | kupang
# Processing Record 49 of Set 11 | atar
# Processing Record 50 of Set 11 | mtambile
# Processing Record 1 of Set 12 | escanaba
# Processing Record 2 of Set 12 | pitimbu
# Processing Record 3 of Set 12 | vallenar
# Processing Record 4 of Set 12 | santa fe
# Processing Record 5 of Set 12 | mandera
# Processing Record 6 of Set 12 | the valley
# Processing Record 7 of Set 12 | saint peter
# Processing Record 8 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 12 | kisangani
# Processing Record 10 of Set 12 | kavieng
# Processing Record 11 of Set 12 | sukhumi
# Processing Record 12 of Set 12 | pabrade
# Processing Record 13 of Set 12 | casper
# Processing Record 14 of Set 12 | lakes entrance
# Processing Record 15 of Set 12 | porangatu
# Processing Record 16 of Set 12 | wasilla
# Processing Record 17 of Set 12 | liberal
# Processing Record 18 of Set 12 | porto santo
# Processing Record 19 of Set 12 | annau
# Processing Record 20 of Set 12 | muzhi
# Processing Record 21 of Set 12 | williams lake
# Processing Record 22 of Set 12 | kloulklubed
# Processing Record 23 of Set 12 | codrington
# Processing Record 24 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | grootfontein
# Processing Record 26 of Set 12 | trelew
# Processing Record 27 of Set 12 | lulea
# Processing Record 28 of Set 12 | sorochinsk
# Processing Record 29 of Set 12 | marystown
# Processing Record 30 of Set 12 | musoma
# Processing Record 31 of Set 12 | oeiras do para
# Processing Record 32 of Set 12 | babushkin
# Processing Record 33 of Set 12 | ahuimanu
# Processing Record 34 of Set 12 | coffeyville
# Processing Record 35 of Set 12 | kapustin yar
# Processing Record 36 of Set 12 | mahajanga
# Processing Record 37 of Set 12 | oksfjord
# Processing Record 38 of Set 12 | siare
# City not found. Skipping...
# Processing Record 39 of Set 12 | ocala
# Processing Record 40 of Set 12 | pinawa
# Processing Record 41 of Set 12 | kibala
# Processing Record 42 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 12 | navsari
# Processing Record 45 of Set 12 | port lincoln
# Processing Record 46 of Set 12 | paamiut
# Processing Record 47 of Set 12 | mayumba
# Processing Record 48 of Set 12 | otane
# Processing Record 49 of Set 12 | doka
# Processing Record 50 of Set 12 | vila velha
# Processing Record 1 of Set 13 | gladstone
# Processing Record 2 of Set 13 | aksum
# Processing Record 3 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 4 of Set 13 | georgetown
# Processing Record 5 of Set 13 | aspindza
# Processing Record 6 of Set 13 | iwaki
# Processing Record 7 of Set 13 | karasburg
# Processing Record 8 of Set 13 | sfantu gheorghe
# Processing Record 9 of Set 13 | almenara
# Processing Record 10 of Set 13 | copiapo
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | chara
# Processing Record 13 of Set 13 | omsukchan
# Processing Record 14 of Set 13 | yashkul
# Processing Record 15 of Set 13 | cahors
# Processing Record 16 of Set 13 | jinchang
# Processing Record 17 of Set 13 | nizwa
# Processing Record 18 of Set 13 | damaturu
# Processing Record 19 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 13 | inongo
# Processing Record 21 of Set 13 | vangaindrano
# Processing Record 22 of Set 13 | gamba
# Processing Record 23 of Set 13 | esperance
# Processing Record 24 of Set 13 | irondequoit
# Processing Record 25 of Set 13 | nong ki
# Processing Record 26 of Set 13 | zabaykalsk
# Processing Record 27 of Set 13 | mogadishu
# Processing Record 28 of Set 13 | kesova gora
# Processing Record 29 of Set 13 | tongren
# Processing Record 30 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 13 | along
# Processing Record 32 of Set 13 | san juan
# Processing Record 33 of Set 13 | fairmont
# Processing Record 34 of Set 13 | borovskoy
# Processing Record 35 of Set 13 | xinxiang
# Processing Record 36 of Set 13 | lodwar
# Processing Record 37 of Set 13 | yanliang
# Processing Record 38 of Set 13 | craig
# Processing Record 39 of Set 13 | eldorado
# Processing Record 40 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 13 | veseloyarsk
# Processing Record 42 of Set 13 | deyang
# Processing Record 43 of Set 13 | kirensk
# Processing Record 44 of Set 13 | sitka
# Processing Record 45 of Set 13 | awjilah
# Processing Record 46 of Set 13 | hachinohe
# Processing Record 47 of Set 13 | peniche
# Processing Record 48 of Set 13 | neftekumsk
# Processing Record 49 of Set 13 | biltine
# Processing Record 50 of Set 13 | banda aceh
# Processing Record 1 of Set 14 | shache
# Processing Record 2 of Set 14 | gushikawa
# Processing Record 3 of Set 14 | bundaberg
# Processing Record 4 of Set 14 | redlands
# Processing Record 5 of Set 14 | bismarck
# Processing Record 6 of Set 14 | kauhajoki
# Processing Record 7 of Set 14 | sarangani
# Processing Record 8 of Set 14 | calabozo
# Processing Record 9 of Set 14 | moerai
# Processing Record 10 of Set 14 | drexel heights
# Processing Record 11 of Set 14 | evensk
# Processing Record 12 of Set 14 | vao
# Processing Record 13 of Set 14 | launceston
# Processing Record 14 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 14 | carutapera
# Processing Record 16 of Set 14 | morondava
# Processing Record 17 of Set 14 | kuah
# Processing Record 18 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 14 | liaozhong
# Processing Record 20 of Set 14 | palmerston
# Processing Record 21 of Set 14 | akom
# Processing Record 22 of Set 14 | port blair
# Processing Record 23 of Set 14 | vilhena
# Processing Record 24 of Set 14 | raudeberg
# Processing Record 25 of Set 14 | half moon bay
# Processing Record 26 of Set 14 | boksitogorsk
# Processing Record 27 of Set 14 | moose factory
# Processing Record 28 of Set 14 | gonbad-e qabus
# Processing Record 29 of Set 14 | nanyuki
# Processing Record 30 of Set 14 | tromso
# Processing Record 31 of Set 14 | erzin
# Processing Record 32 of Set 14 | strezhevoy
# Processing Record 33 of Set 14 | ikungi
# Processing Record 34 of Set 14 | panguna
# Processing Record 35 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 14 | boende
# Processing Record 37 of Set 14 | los llanos de aridane
# Processing Record 38 of Set 14 | svetlyy
# Processing Record 39 of Set 14 | fonte boa
# Processing Record 40 of Set 14 | alfenas
# Processing Record 41 of Set 14 | ouallam
# Processing Record 42 of Set 14 | muros
# Processing Record 43 of Set 14 | hong gai
# Processing Record 44 of Set 14 | marsh harbour
# Processing Record 45 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 14 | coffs harbour
# Processing Record 47 of Set 14 | eureka
# Processing Record 48 of Set 14 | solnechnyy
# Processing Record 49 of Set 14 | ferma
# Processing Record 50 of Set 14 | khurba
# Processing Record 1 of Set 15 | saint-leu
# Processing Record 2 of Set 15 | nurota
# Processing Record 3 of Set 15 | turukhansk
# Processing Record 4 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 5 of Set 15 | saint anthony
# Processing Record 6 of Set 15 | oranjemund
# Processing Record 7 of Set 15 | bay roberts
# Processing Record 8 of Set 15 | tiarei
# Processing Record 9 of Set 15 | nova bystrice
# Processing Record 10 of Set 15 | namibe
# Processing Record 11 of Set 15 | mwense
# Processing Record 12 of Set 15 | norman wells
# Processing Record 13 of Set 15 | erenhot
# Processing Record 14 of Set 15 | sioux lookout
# Processing Record 15 of Set 15 | qingquan
# Processing Record 16 of Set 15 | moron
# Processing Record 17 of Set 15 | kuryk
# Processing Record 18 of Set 15 | pangkalanbuun
# Processing Record 19 of Set 15 | abnub
# Processing Record 20 of Set 15 | boundiali
# Processing Record 21 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 15 | xiangxiang
# Processing Record 23 of Set 15 | luau
# Processing Record 24 of Set 15 | kadoshkino
# Processing Record 25 of Set 15 | inuvik
# Processing Record 26 of Set 15 | boyolangu
# Processing Record 27 of Set 15 | aberdeen
# Processing Record 28 of Set 15 | soyo
# Processing Record 29 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 15 | tudela
# Processing Record 31 of Set 15 | kita
# Processing Record 32 of Set 15 | banjar
# Processing Record 33 of Set 15 | jacareacanga
# Processing Record 34 of Set 15 | arlit
# Processing Record 35 of Set 15 | whitianga
# Processing Record 36 of Set 15 | pokhara
# Processing Record 37 of Set 15 | ushtobe
# Processing Record 38 of Set 15 | tanete
# Processing Record 39 of Set 15 | khani
# Processing Record 40 of Set 15 | dhidhdhoo
# Processing Record 41 of Set 15 | novonukutskiy
# Processing Record 42 of Set 15 | jiamusi
# Processing Record 43 of Set 15 | lasa
# Processing Record 44 of Set 15 | nanning
# Processing Record 45 of Set 15 | codajas
# Processing Record 46 of Set 15 | uni
# Processing Record 47 of Set 15 | campbell river
# Processing Record 48 of Set 15 | el badari
# City not found. Skipping...
# Processing Record 49 of Set 15 | maumere
# Processing Record 50 of Set 15 | ouadda
# Processing Record 1 of Set 16 | karoi
# Processing Record 2 of Set 16 | sistranda
# Processing Record 3 of Set 16 | yazman
# Processing Record 4 of Set 16 | chengde
# Processing Record 5 of Set 16 | goderich
# Processing Record 6 of Set 16 | skjervoy
# Processing Record 7 of Set 16 | fort-shevchenko
# Processing Record 8 of Set 16 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 16 | kondinskoye
# Processing Record 11 of Set 16 | ushibuka
# Processing Record 12 of Set 16 | sao miguel do tapuio
# Processing Record 13 of Set 16 | yermakovskoye
# Processing Record 14 of Set 16 | burica
# City not found. Skipping...
# Processing Record 15 of Set 16 | xalpatlahuac
# Processing Record 16 of Set 16 | deniliquin
# Processing Record 17 of Set 16 | maneadero
# Processing Record 18 of Set 16 | zolotinka
# City not found. Skipping...
# Processing Record 19 of Set 16 | arona
# Processing Record 20 of Set 16 | kumluca
# Processing Record 21 of Set 16 | laguna de perlas
# Processing Record 22 of Set 16 | monfalcone
# Processing Record 23 of Set 16 | sola
# Processing Record 24 of Set 16 | new bern
# Processing Record 25 of Set 16 | oussouye
# Processing Record 26 of Set 16 | boca do acre
# Processing Record 27 of Set 16 | sheopur
# Processing Record 28 of Set 16 | angra
# City not found. Skipping...
# Processing Record 29 of Set 16 | sur
# Processing Record 30 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 16 | altamont
# Processing Record 32 of Set 16 | sobolevo
# Processing Record 33 of Set 16 | dubbo
# Processing Record 34 of Set 16 | udachnyy
# Processing Record 35 of Set 16 | purepero
# Processing Record 36 of Set 16 | kijang
# Processing Record 37 of Set 16 | san quintin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 721

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     byron bay -28.6500  153.6167     79.95        62          65
# 1  punta arenas -53.1500  -70.9167     53.11        37           0
# 2        faanui -16.4833 -151.7500     81.16        58          97
# 3   new norfolk -42.7826  147.0587     72.72        46          31
# 4       cayenne   4.9333  -52.3333     73.44       100          75
# 5      ust-nera  64.5667  143.2000    -22.65        98         100
# 6      belmonte -15.8631  -38.8828     75.31        87          25
# 7       fortuna  40.5982 -124.1573     52.66        76          40
# 8     vestmanna  62.1564   -7.1664     23.92        93          20
# 9       ushuaia -54.8000  -68.3000     51.42        57          40
#
#    Wind Speed Country           Weather
# 0        9.46      AU     broken clouds
# 1       23.02      CL         clear sky
# 2       14.29      PF   overcast clouds
# 3        2.98      AU  scattered clouds
# 4        0.00      GF     broken clouds
# 5        7.09      RU   overcast clouds
# 6        7.38      BR  scattered clouds
# 7       12.66      US  scattered clouds
# 8        1.14      FO        light snow
# 9       24.16      AR  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather"]

#maybe change name to current weather

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_reorder]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     byron bay      AU -28.6500  153.6167     79.95        62          65
# 1  punta arenas      CL -53.1500  -70.9167     53.11        37           0
# 2        faanui      PF -16.4833 -151.7500     81.16        58          97
# 3   new norfolk      AU -42.7826  147.0587     72.72        46          31
# 4       cayenne      GF   4.9333  -52.3333     73.44       100          75
# 5      ust-nera      RU  64.5667  143.2000    -22.65        98         100
# 6      belmonte      BR -15.8631  -38.8828     75.31        87          25
# 7       fortuna      US  40.5982 -124.1573     52.66        76          40
# 8     vestmanna      FO  62.1564   -7.1664     23.92        93          20
# 9       ushuaia      AR -54.8000  -68.3000     51.42        57          40
#
#    Wind Speed           Weather
# 0        9.46     broken clouds
# 1       23.02         clear sky
# 2       14.29   overcast clouds
# 3        2.98  scattered clouds
# 4        0.00     broken clouds
# 5        7.09   overcast clouds
# 6        7.38  scattered clouds
# 7       12.66  scattered clouds
# 8        1.14        light snow
# 9       24.16  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Weather        object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../weather_database/WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
